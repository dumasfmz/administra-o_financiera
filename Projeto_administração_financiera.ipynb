# %% [markdown]
# <a href="https://colab.research.google.com/github/dumasfmz/administra-o_financiera/blob/main/Projeto_administra%C3%A7%C3%A3o_financiera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Categoria das despesas
#Custos fixos 40%.         Alguns exemplos:Aluguel, financiamentos, conta de eletricidade, alimentação, conta de agua..
#Conforto 20%.             Alguns exemplos:Assinaturas netflix, diarista que arruma a casa, aluguel de um carro.. são coisas que eu poderia fazer mais barato mas acabo pagando por conforto
#Metas 10%.                Alguns exemplos:planejar umas ferias, comprar uma casas..
#Plazeres 5%.              Alguns exemplos:viagem para a praia, janatar em um restaurante, asistir um filme no cinema..
#Liberdade Financeira 15%. Alguns exemplos:Investimentos en açoes, FIIs, negocio pessoal..
#Educação 10%.             Alguns exemplos:comprar um livro, fazer um curso, faculdade...

#função para o submenu para cada categoria
def option(Matriz):
  n = 0
  Auxiliar = 0
  while True:
    print("Opções:")
    print("Digite o nome do gasto")
    print("Se não fez gasto nesta categoria, pode inseri qualquer nome e deve inserir o gasto como zero")
    print("Digite 'Não' se não tiver mais gasto")

    entrada = input(": ")

    if entrada == "Não" and n ==0:
      Matriz = [["total", 0]]
      break
    elif entrada == "Não" and n > 0:
      Matriz.append(["Total", Auxiliar])
      break

    elif n >= 0 and entrada != "Não":
      n +=1
      try:
        input3 = float(input("Inserir o valor gasto: "))
#A exceção quando o usuario insire um string
      except:
        print("Error, por favor inserir um numero valido. Lembre de utilizar ponto como separador decimal")
      else:
        Matriz.append([entrada, input3])
        Auxiliar = input3 + Auxiliar

  for i in Matriz:
    print(i)

#função para o calcular a diferencia dos gastos
def diferencia(Vi,Vr):
  if Vr > Vi:
    print("Você teve um gasto a mais de: ", Vr - Vi, "==> Precisa diminuir")
  elif Vi > Vr:
    print("Você teve um gasto a menos de: ", Vi -Vr, "==> Pode ajustar o gasto")
 # elif Vr == 0:
  #  print("Error, por favor inserir um numero valido. Lembre de utilizar ponto como separador decimal")


#função para verificar se o cliente tinha inserido os dados em uma categoria
def Verificar(Matriz):
  if Matriz != []:
    print("Vejo que esqueceu inserir algun gasto. Precisa inserir todos os dados da categoria novamente")
    Matriz = []

#  if Matriz != []:
#    while True:
#      A = input("Esqueceu de algum gasto? sim:1 ou Não: 2 ")
#      if A != "1" and A != "2":
#        print("Entrada inválida")
#        A = input("Esqueceu de algum gasto? sim:1 ou Não: 2 ")
#      elif A == "1":
#        Matriz = []
#        print("Precisa inserir todos os dados do segmento novamente")
#        break
#      elif A == "2":
#        print("Voltamos ao menu anterior")
#        break

#return




#Declaração das variaveis
#matriz de gastos ideal o recomendado
Gi = []
#matriz custos fixos
Cf = []
#matriz conforto
Conforto = []
#matriz Metas
Metas = []
#matriz Plazeres
Plazeres = []
#matriz Liberdade financeira
Lf= []
#matriz Educação
Educação = []
#matriz total de despesas no mes
Total = [0, 0, 0, 0, 0, 0]

#inicio do aplicativo
try:
  Rt = float((input("Inserir a renda total: ")))

#A exceção quando o usuario insire um string
except:
  print("Error, por favor inserir um numero valido. Lembre de utilizar ponto como separador decimal")

else:
#Menu para principal do usuário
  while True:
      print("Opções:")
      print("Digite '1' para inserir os gastos relacionados a custos fixos")
      print("Digite '2' para inserir os gastos relacionados a conforto")
      print("Digite '3' para inserir os gastos relacionados a metas")
      print("Digite '4' para inserir os gastos relacionados a plazere")
      print("Digite '5' para inserir os gastos relacionados a liberdade financiera")
      print("Digite '6' para inserir os gastos relacionados a educação")
      print("Digite 'Sair' para encerrar o programa")
      entrada = input(": ")

      if entrada == "Sair":
        print("Total de gastos no mes: ", sum(Total))
        break
      elif entrada in ("1", "2", "3", "4", "5", "6"):

        Cfi = Rt*0.4
        Confortoi = Rt*0.2
        Metasi = Rt*0.1
        Plazeresi = Rt*0.05
        Lfi = Rt*0.15
        Educaçãoi = Rt*0.1
        Gi = [["Custos fixos recomendado", Cfi], ["Conforto recomendado", Confortoi], ["Metas recomendado", Metasi], ["Plazeres recomendado", Plazeresi], ["Liberdade financeira recomendado", Lfi], ["Educação recomendado", Educaçãoi]]
 #imprime os gastos redomendados
        for i in Gi:
          print(i)


        if entrada == "1":
          Verificar(Cf)
          option(Cf)
          if Cf:  # Verifica si la lista no está vacía antes de acceder a los elementos
            diferencia(Cfi, Cf[-1][-1])
            if Cf[-1][-1] == 0:
              print("Você é um filho de pai e mãe, pode curtir por enquanto")
            Total[0] = Cf[-1][-1]
          else:
            print("Lista de custos fixos vazia!")

        elif entrada == "2":
          Verificar(Conforto)
          option(Conforto)
          if Conforto:  # Avalia se a lista não está vazia antes de acessar os elementos
            diferencia(Confortoi, Conforto[-1][-1])
            if Conforto[-1][-1] == 0:
              print("Você tem direito algum conforto em sua vida, pode abri a mão")
            Total[1] = Conforto[-1][-1]
          else:
            print("Lista de conforto vazia!")


        elif entrada == "3":
          Verificar(Metas)
          option(Metas)
          if Metas:  # Avalia se a lista não está vazia antes de acessar os elementos
            diferencia(Metasi, Metas[-1][-1])
            if Metas[-1][-1] == 0:
              print("Você precisa estabelecer metas em sua vida, vai ficar mais satisfeito no futuro com seus resultados")
            Total[2] = Metas[-1][-1]
          else:
            print("Lista de metas vazia!")

        elif entrada == "4":
          Verificar(Plazeres)
          option(Plazeres)
          if Plazeres:
            diferencia(Plazeresi, Plazeres[-1][-1])
            if Plazeres[-1][-1] == 0:
              print("Uma vida sem plazeres pode trazer desbalance emocional e stress, você precisa adicionar algum plazere em sua vida")
            Total[3] = Plazeres[-1][-1]
          else:
            print("Lista de plazeres vazia!")

        elif entrada == "5":
          Verificar(Lf)
          option(Lf)
          if Lf:
            diferencia(Lfi, Lf[-1][-1])
            if Lf[-1][-1] == 0:
              print("Todo mundo precisa aprender a investir para conseguir liberdade financeira no futuro. Você precisa iniciar com os investimento quanto antes ")
            Total[4] = Lf[-1][-1]
          else:
            print("Lista de investimento vazia!")

        elif entrada == "6":
          Verificar(Educação)
          option(Educação)
          if Educação:
            diferencia(Educaçãoi, Educação[-1][-1])
            if Educação[-1][-1] == 0:
              print("Você precisa investir em conhecimento para melhorar sua situação atual, bora aprender")
            Total[5] = Educação[-1][-1]
          else:
            print("Lista de educação vazia!")

      else:
          print("Entrada inválida")
# Out:
# Inserir a renda total: 3000
# Opções:
# Digite '1' para inserir os gastos relacionados a custos fixos
# Digite '2' para inserir os gastos relacionados a conforto
# Digite '3' para inserir os gastos relacionados a metas
# Digite '4' para inserir os gastos relacionados a plazere
# Digite '5' para inserir os gastos relacionados a liberdade financiera
# Digite '6' para inserir os gastos relacionados a educação
# Digite 'Sair' para encerrar o programa
# : 1
# ['Custos fixos recomendado', 1200.0]
# ['Conforto recomendado', 600.0]
# ['Metas recomendado', 300.0]
# ['Plazeres recomendado', 150.0]
# ['Liberdade financeira recomendado', 450.0]
# ['Educação recomendado', 300.0]
# Opções:
# Digite o nome do gasto
# Se não fez gasto nesta categoria, pode inseri qualquer nome e deve inserir o gasto como zero
# Digite 'Não' se não tiver mais gasto
# : Aluguel
# Inserir o valor gasto: 1000
# Opções:
# Digite o nome do gasto
# ...
